# %% [markdown]
# ## Intro to Tracktable - Fall 2023
# Documentation Link: *https://tracktable.readthedocs.io/en/latest/*

# %% [markdown]
# We just spent the last couple notebooks manipulating flight data and while we were mostly successful it took a while to build up out database and manipulate our flight trajectories. The library you'll use in this notebook (Tracktable) was created and maintained by some of the lovely folks at Sandia to analyze geospatial data.
#
# In the following cells replace '❌' with their corsponding values for our dataset and procedures.

# %%
#Import needed libraries
import os.path
import tracktable

from tracktable.core import geomath
from tracktable.domain.terrestrial import TrajectoryPointReader
from tracktable.applications.assemble_trajectories import AssembleTrajectoryFromPoints
from tracktable.render.render_trajectories import render_trajectories

from datetime import datetime, timedelta

tracktable.__version__
# Out:
# '1.6.0'

# %% [markdown]
# Let's take a look at the file we're using, it should contain flight information.

# %%
# %%bash
# head "/anvil/projects/tdm/corporate/sandia-trajectory/previous_files/flight/data/raw_data/asdi_2014_07_01_h121314_safe.tsv"
# Out:
# OBJECT_ID	UPDATE_TIME	LONGITUDE	LATITUDE	SPEED	HEADING	ALTITUDE
# N404TC	2014-07-01 12:00:00	-67.05	45.6833	430	56	39000
# N617BG	2014-07-01 12:00:00	-97.7833	30.1161	156	246	5500
# EJA644	2014-07-01 12:00:00
# N748W	2014-07-01 12:00:00	-92	40.1611	451	6	38500
# N802UP	2014-07-01 12:00:00
# SWA4414	2014-07-01 12:00:00	-89.4131	37.8119	457	115	33000
# N536M	2014-07-01 12:00:00
# N2095J	2014-07-01 12:00:00					7000
# N81TE	2014-07-01 12:00:00

# %% [markdown]
# The reader tells Tracktable where our data is stored and what information exists in each column.

# %%
#Read in the file, let it know what the comment & delimiter character is
data_filename = os.path.join("/anvil/projects/tdm/corporate/sandia-trajectory/previous_files/flight/data/raw_data/asdi_2014_07_01_h121314_safe.tsv")
inFile = open(data_filename, 'r')
reader = TrajectoryPointReader()
reader.input = inFile
reader.comment_character = '#' 	#What character is used for comments
reader.field_delimiter = '\t' 	#What character "breaks" each data value ex: Comma-Separated Values

#Columns start at 0, ex: 0 is column A, 2 is column C
reader.object_id_column = 0 	#What column holds the object ID
reader.timestamp_column = 1 	#What column holds the timestamp
reader.coordinates[1] = 3		#What column holds LAT data
reader.coordinates[0] = 2		#What column holds LONG data
reader.set_real_field_column('speed', 4) #Extra data (heading)
reader.set_real_field_column('heading', 5) #Extra data (heading)
reader.set_real_field_column('altitude', 6) #Extra data (altitude)

# %% [markdown]
# Nothing to change in the next cell, just a way to check our work.

# %%
#Test to see if data has been imported correctly.
limit = 5					# Used to limit how many results we see
for i, x in enumerate(reader):
    if i >= limit: break	# Exits a loop early
    print(x)				# Print a line from reader
# Out:
# [N404TC@ 2014-07-01 12:00:00: (-67.05, 45.6833) Properties: ( {altitude [real]: 39000}, {heading [real]: 56}, {speed [real]: 430})]
# [N617BG@ 2014-07-01 12:00:00: (-97.7833, 30.1161) Properties: ( {altitude [real]: 5500}, {heading [real]: 246}, {speed [real]: 156})]
# [N748W@ 2014-07-01 12:00:00: (-92, 40.1611) Properties: ( {altitude [real]: 38500}, {heading [real]: 6}, {speed [real]: 451})]
# [SWA4414@ 2014-07-01 12:00:00: (-89.4131, 37.8119) Properties: ( {altitude [real]: 33000}, {heading [real]: 115}, {speed [real]: 457})]
# [AAL40@ 2014-07-01 12:00:00: (-85.7925, 41.8717) Properties: ( {altitude [real]: 27000}, {heading [real]: 107}, {speed [real]: 480})]

# %% [markdown]
# The builder stitches together rows with the same object_id then will split it into flights based on temporal gaps or distance. There are default thresholds but let's update it to what we have used before.
#  * minium length of 10
#  * temporal gap limit of 30 minutes

# %%
#Combine datapoints together using the object_id
builder = AssembleTrajectoryFromPoints()
builder.input = reader
builder.minimum_length = 10
builder.separation_time = timedelta(minutes = 30)
traj = list(builder.trajectories())
print(len(traj), '〖10815〗flights built! ✈')

print(f'The type of traj is {type(traj)}')
print(f'traj is a list of {type(traj[0])}')
# Out:
# INFO:tracktable.applications.assemble_trajectoriesAssembleTrajectoryFromPoints:New trajectories will be declared after a separation of None distance units between two points or a time lapse of at least 0:30:00 (hours, minutes, seconds).
# INFO:tracktable.applications.assemble_trajectoriesAssembleTrajectoryFromPoints:Trajectories with fewer than 10 points will be discarded.
# [2023-10-06 11:47:02.262779] [0x00007f0d315aa740] [info]    Done reading points. Generated 778983 points correctly and discarded 29775 due to parse errors.
# INFO:tracktable.applications.assemble_trajectoriesAssembleTrajectoryFromPoints:Done assembling trajectories. 10815 trajectories produced and 1355 discarded for having fewer than 10 points.
# 10815 〖10815〗flights built! ✈
# The type of traj is <class 'list'>
# traj is a list of <class 'tracktable.lib._terrestrial.TrajectoryTerrestrial'>

# %% [markdown]
# Unpacking our first flight in traj we can see all the points included. They should be in time sequential order and share the same object_id, which is what we would expect from a trajectory.

# %%
print(*traj[0])
# Out:
# [N567LT@ 2014-07-01 12:00:37: (-78.1106, 35.9125) Properties: ( {altitude [real]: 6000}, {heading [real]: 211}, {speed [real]: 180})] [N567LT@ 2014-07-01 12:01:26: (-78.1325, 35.885) Properties: ( {altitude [real]: 6000}, {heading [real]: 213}, {speed [real]: 189})] [N567LT@ 2014-07-01 12:01:38: (-78.145, 35.8681) Properties: ( {altitude [real]: 6000}, {heading [real]: 211}, {speed [real]: 180})] [N567LT@ 2014-07-01 12:02:37: (-78.1769, 35.8278) Properties: ( {altitude [real]: 6000}, {heading [real]: 205}, {speed [real]: 182})] [N567LT@ 2014-07-01 12:03:38: (-78.2114, 35.7853) Properties: ( {altitude [real]: 6000}, {heading [real]: 208}, {speed [real]: 177})] [N567LT@ 2014-07-01 12:04:39: (-78.2436, 35.7492) Properties: ( {altitude [real]: 5200}, {heading [real]: 215}, {speed [real]: 166})] [N567LT@ 2014-07-01 12:05:25: (-78.2656, 35.7214) Properties: ( {altitude [real]: 4500}, {heading [real]: 213}, {speed [real]: 183})] [N567LT@ 2014-07-01 12:05:40: (-78.2778, 35.7044) Properties: ( {altitude [real]: 4200}, {heading [real]: 210}, {speed [real]: 190})] [N567LT@ 2014-07-01 12:06:26: (-78.305, 35.6789) Properties: ( {altitude [real]: 3700}, {heading [real]: 221}, {speed [real]: 183})] [N567LT@ 2014-07-01 12:07:24: (-78.3344, 35.6428) Properties: ( {altitude [real]: 3600}, {heading [real]: 214}, {speed [real]: 176})]

# %% [markdown]
# A single flight is way more than just a list of points, its actually a class so it store more information.

# %%
print(f'Object_id: {traj[0][0].object_id}')                     # Trajectory 0 in list, point 0 in trajectory
print(f'Latitude: {traj[0][0][1]}')                        # Trajectory 0 in list, point 0 in trajectory, coordinate[1]
print(f"Heading: {traj[0][0].properties['heading']}")      
print(f'Data Points: {len(traj[0])}')
# Out:
# Object_id: N567LT
# Latitude: 35.9125
# Heading: 211.0
# Data Points: 10

# %% [markdown]
# Now (with the power of tracktable) flight features that may have taken multiple lines to obtain can be computed with ease.
#
# Let's compute the flight's length and convex hull ratio using one line of python for each.
# *https://tracktable.readthedocs.io/en/latest/api/python/tracktable.core.geomath.html*

# %%
flightOfInterest = traj[3000]

####################         YOUR CODE         ####################

flightLength = tracktable.core.geomath.length(flightOfInterest)

convexHullRatio = tracktable.core.geomath.convex_hull_aspect_ratio(flightOfInterest)

####################         END CODE          ####################

print(f'Flight {flightOfInterest[0].object_id} has a length of {flightLength:.2f}〖1566.34〗km.')
print(f'and a convex hull ratio of {convexHullRatio:.2f}〖24.33〗km^2 / km.')
# Out:
# Flight AWE2064 has a length of 1566.34〖1566.34〗km.
# and a convex hull ratio of 24.33〖24.33〗km^2 / km.

# %% [markdown]
# As a bouns it comes with a great way to view flights too!

# %%
#Render the first flight in the list
render_trajectories(flightOfInterest)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fdf83799be430990764848001d6d969 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fdf83799be430990764848001d6d969&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0fdf83799be430990764848001d6d969 = L.map(
#                 &quot;map_0fdf83799be430990764848001d6d969&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0fdf83799be430990764848001d6d969);
#
#
#
#
#
#             var tile_layer_094955f0ce472b472d9eca2ac9c79ab6 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0fdf83799be430990764848001d6d969);
#
#
#             var poly_line_0d2d6318c0e8a82a5c8def749fc77b77 = L.polyline(
#                 [[32.8833, -97.0167], [32.8667, -97.0167]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#11004a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#11004a&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.4}
#             ).addTo(map_0fdf83799be430990764848001d6d969);
#
#
#         var popup_bbb6d5e887415a4a3cdb29471ed6e992 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_939b56e9278709da9f5646ad78e1ed02 = $(`&lt;div id=&quot;html_939b56e9278709da9f5646ad78e1ed02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AWE2064&lt;br&gt;2014-07-01 12:15:36&lt;br&gt; to &lt;br&gt;2014-07-01 14:16:02&lt;/div&gt;`)[0];
#             popup_bbb6d5e887415a4a3cdb29471ed6e992.setContent(html_939b56e9278709da9f5646ad78e1ed02);
#
#
#         poly_line_0d2d6318c0e8a82a5c8def749fc77b77.bindPopup(popup_bbb6d5e887415a4a3cdb29471ed6e992)
#         ;
#
#
#
#
#             poly_line_0d2d6318c0e8a82a5c8def749fc77b77.bindTooltip(
#                 `&lt;div&gt;
#                      AWE2064
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_e4bfb844eb420239ce94646efde7d125 = L.polyline(
#                 [[32.8667, -97.0167], [32.8, -97.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#11004b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#11004b&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.4}
#             ).addTo(map_0fdf83799be430990764848001d6d969);
#
#
#         var popup_ab724ba4be3767d89356dcd5a8e12582 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_648627c9c8d028f0abc3b8231d1b40c6 = $(`&lt;div id=&quot;html_648627c9c8d028f0abc3b8231d1b40c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AWE2064&lt;br&gt;2014-07-01 12:15:36&lt;br&gt; to &lt;br&gt;2014-07-01 14:16:02&lt;/div&gt;`)[0];
#             popup_ab724ba4be3767d89356dcd5a8e12582.setContent(html_648627c9c8d028f0abc3b8231d1b40c6);
#
#
#         poly_line_e4bfb844eb420239ce94646efde7d125.bindPopup(popup_ab724ba4be3767d89356dcd5a8e12582)
#         ;
#
#
#
#
#             poly_line_e4bfb844eb420239ce94646efde7d125.bindTooltip(
#                 `&lt;div&gt;
#                      AWE2064
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_bb5e45ab36235be3284963809a3745a8 = L.polyline(
#                 [[32.8, -97.0], [32.7667, -96.9333]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#11004d&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#11004d&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.4}
#             ).addTo(map_0fdf83799be430990764848001d6d969);
#
#
#         var popup_d81363a628277c957df32249afc90ca1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e6d83718b25a1cfe61f565960f1f787

# %% [markdown]
# We can actually render multiple flights at once! Render four flights from the center of our dataset.

# %%
####################         YOUR CODE         ####################

centerFour = [traj[0],traj[1],traj[2],traj[3]]

####################         END CODE          ####################
render_trajectories(centerFour)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eee1cd766790af4321d9caf01448ccdd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eee1cd766790af4321d9caf01448ccdd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_eee1cd766790af4321d9caf01448ccdd = L.map(
#                 &quot;map_eee1cd766790af4321d9caf01448ccdd&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_eee1cd766790af4321d9caf01448ccdd);
#
#
#
#
#
#             var tile_layer_a36b3dd7ca3b24c7c201e0140c3bb1b5 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eee1cd766790af4321d9caf01448ccdd);
#
#
#             var poly_line_e501130e13e244a8f8791c1cb79e8e26 = L.polyline(
#                 [[35.9125, -78.1106], [35.885, -78.1325]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00336e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00336e&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.4}
#             ).addTo(map_eee1cd766790af4321d9caf01448ccdd);
#
#
#         var popup_fd3ba3b6674dedf03045767df8cbad65 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d151d697d946ae0bb42ec94696d430af = $(`&lt;div id=&quot;html_d151d697d946ae0bb42ec94696d430af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;N567LT&lt;br&gt;2014-07-01 12:00:37&lt;br&gt; to &lt;br&gt;2014-07-01 12:07:24&lt;/div&gt;`)[0];
#             popup_fd3ba3b6674dedf03045767df8cbad65.setContent(html_d151d697d946ae0bb42ec94696d430af);
#
#
#         poly_line_e501130e13e244a8f8791c1cb79e8e26.bindPopup(popup_fd3ba3b6674dedf03045767df8cbad65)
#         ;
#
#
#
#
#             poly_line_e501130e13e244a8f8791c1cb79e8e26.bindTooltip(
#                 `&lt;div&gt;
#                      N567LT
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_ae2d7829d1a86c0b3b1dd597d26afef7 = L.polyline(
#                 [[35.885, -78.1325], [35.8681, -78.145]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#003e84&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#003e84&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.4}
#             ).addTo(map_eee1cd766790af4321d9caf01448ccdd);
#
#
#         var popup_6e824530531b14d7b8a292421281a892 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_149c8c73800e0a4f4b6f72460a00a398 = $(`&lt;div id=&quot;html_149c8c73800e0a4f4b6f72460a00a398&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;N567LT&lt;br&gt;2014-07-01 12:00:37&lt;br&gt; to &lt;br&gt;2014-07-01 12:07:24&lt;/div&gt;`)[0];
#             popup_6e824530531b14d7b8a292421281a892.setContent(html_149c8c73800e0a4f4b6f72460a00a398);
#
#
#         poly_line_ae2d7829d1a86c0b3b1dd597d26afef7.bindPopup(popup_6e824530531b14d7b8a292421281a892)
#         ;
#
#
#
#
#             poly_line_ae2d7829d1a86c0b3b1dd597d26afef7.bindTooltip(
#                 `&lt;div&gt;
#                      N567LT
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_71e27edf25d99ecb6333df2f5d8ccf79 = L.polyline(
#                 [[35.8681, -78.145], [35.8278, -78.1769]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0057b9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#0057b9&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.4}
#             ).addTo(map_eee1cd766790af4321d9caf01448ccdd);
#
#
#         var popup_800ee10de7cc49441d7ad2f0a3d5cc62 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2b0620e8b6a8dba1cd9b41ca4e1

# %% [markdown]
# Determine which flight has the most datapoints in our dataset.

# %%
####################         YOUR CODE         ####################
largest = max(traj, key = len)

####################         END CODE          ####################        
        
print(f'The largest flight has {len(largest)}〖292〗datapoints!')
render_trajectories(largest)
# Out:
# The largest flight has 292〖292〗datapoints!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea92b3d928f36e9a149cb734dfc87967 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea92b3d928f36e9a149cb734dfc87967&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ea92b3d928f36e9a149cb734dfc87967 = L.map(
#                 &quot;map_ea92b3d928f36e9a149cb734dfc87967&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ea92b3d928f36e9a149cb734dfc87967);
#
#
#
#
#
#             var tile_layer_e681092794b59db3a6e0db3ff6914553 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ea92b3d928f36e9a149cb734dfc87967);
#
#
#             var poly_line_6e1ba29c5b9813f2dccd9dfe7acde0ac = L.polyline(
#                 [[38.545, -80.3939], [38.5725, -80.3661]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#12004a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#12004a&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.4}
#             ).addTo(map_ea92b3d928f36e9a149cb734dfc87967);
#
#
#         var popup_f950bacb371d6accb03ee89c7d3df40f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_18f22305a82a0e74d886ca847550e9e7 = $(`&lt;div id=&quot;html_18f22305a82a0e74d886ca847550e9e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;N491EC&lt;br&gt;2014-07-01 12:00:40&lt;br&gt; to &lt;br&gt;2014-07-01 14:59:56&lt;/div&gt;`)[0];
#             popup_f950bacb371d6accb03ee89c7d3df40f.setContent(html_18f22305a82a0e74d886ca847550e9e7);
#
#
#         poly_line_6e1ba29c5b9813f2dccd9dfe7acde0ac.bindPopup(popup_f950bacb371d6accb03ee89c7d3df40f)
#         ;
#
#
#
#
#             poly_line_6e1ba29c5b9813f2dccd9dfe7acde0ac.bindTooltip(
#                 `&lt;div&gt;
#                      N491EC
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_2f5914c20082006aac9d0d4de2c9638e = L.polyline(
#                 [[38.5725, -80.3661], [38.6683, -80.2747]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#13004b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#13004b&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.4}
#             ).addTo(map_ea92b3d928f36e9a149cb734dfc87967);
#
#
#         var popup_73e4209fc4e8d36ac7a671eb2b9f3488 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b8d09bff7a4eb6149475a03dcd17e18a = $(`&lt;div id=&quot;html_b8d09bff7a4eb6149475a03dcd17e18a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;N491EC&lt;br&gt;2014-07-01 12:00:40&lt;br&gt; to &lt;br&gt;2014-07-01 14:59:56&lt;/div&gt;`)[0];
#             popup_73e4209fc4e8d36ac7a671eb2b9f3488.setContent(html_b8d09bff7a4eb6149475a03dcd17e18a);
#
#
#         poly_line_2f5914c20082006aac9d0d4de2c9638e.bindPopup(popup_73e4209fc4e8d36ac7a671eb2b9f3488)
#         ;
#
#
#
#
#             poly_line_2f5914c20082006aac9d0d4de2c9638e.bindTooltip(
#                 `&lt;div&gt;
#                      N491EC
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_b0c74a5af6c49ebc1d6289ec1358bf20 = L.polyline(
#                 [[38.6683, -80.2747], [38.7472, -80.1975]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#13004d&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#13004d&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.4}
#             ).addTo(map_ea92b3d928f36e9a149cb734dfc87967);
#
#
#         var popup_afbbfc716d0a55a58b9131e779bb73ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4d717b0b955e8f46c1cd7e8d

# %%
len(traj[0])
# Out:
# 10

# %% [markdown]
# Determine which flight is the longest in our dataset.

# %%
####################         YOUR CODE         ####################

longest = max(traj, key = tracktable.core.geomath.length)

####################         END CODE          ####################

print(f'The longest flight is {geomath.length(longest):.2f}〖6767.54〗km!')
render_trajectories(longest)
# Out:
# The longest flight is 6767.54〖6767.54〗km!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee2c81c31445e4f84b2d1a7cedd69ac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee2c81c31445e4f84b2d1a7cedd69ac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ee2c81c31445e4f84b2d1a7cedd69ac4 = L.map(
#                 &quot;map_ee2c81c31445e4f84b2d1a7cedd69ac4&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ee2c81c31445e4f84b2d1a7cedd69ac4);
#
#
#
#
#
#             var tile_layer_866c53e5cc6f0581b08d175856fef4da = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ee2c81c31445e4f84b2d1a7cedd69ac4);
#
#
#             var poly_line_2f47b3b8015f96e33696bfeb628fb098 = L.polyline(
#                 [[42.3844, -71.825], [42.4953, -71.735]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0d4a00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#0d4a00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.4}
#             ).addTo(map_ee2c81c31445e4f84b2d1a7cedd69ac4);
#
#
#         var popup_8c190ffb51fbbf1f87d52e1ad5bdbea8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_72691cad540ebfa9a38ae86d3a64092c = $(`&lt;div id=&quot;html_72691cad540ebfa9a38ae86d3a64092c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BAW180&lt;br&gt;2014-07-01 12:01:05&lt;br&gt; to &lt;br&gt;2014-07-01 14:59:03&lt;/div&gt;`)[0];
#             popup_8c190ffb51fbbf1f87d52e1ad5bdbea8.setContent(html_72691cad540ebfa9a38ae86d3a64092c);
#
#
#         poly_line_2f47b3b8015f96e33696bfeb628fb098.bindPopup(popup_8c190ffb51fbbf1f87d52e1ad5bdbea8)
#         ;
#
#
#
#
#             poly_line_2f47b3b8015f96e33696bfeb628fb098.bindTooltip(
#                 `&lt;div&gt;
#                      BAW180
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_ca8ae0f3a661d1d86b73c0d637d31c3a = L.polyline(
#                 [[42.4953, -71.735], [42.605, -71.6444]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0d4b00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#0d4b00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.4}
#             ).addTo(map_ee2c81c31445e4f84b2d1a7cedd69ac4);
#
#
#         var popup_fdad240e6f31fb43580e690a672ba52a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f69f1fcc4242fd1940f600a2a1964410 = $(`&lt;div id=&quot;html_f69f1fcc4242fd1940f600a2a1964410&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BAW180&lt;br&gt;2014-07-01 12:01:05&lt;br&gt; to &lt;br&gt;2014-07-01 14:59:03&lt;/div&gt;`)[0];
#             popup_fdad240e6f31fb43580e690a672ba52a.setContent(html_f69f1fcc4242fd1940f600a2a1964410);
#
#
#         poly_line_ca8ae0f3a661d1d86b73c0d637d31c3a.bindPopup(popup_fdad240e6f31fb43580e690a672ba52a)
#         ;
#
#
#
#
#             poly_line_ca8ae0f3a661d1d86b73c0d637d31c3a.bindTooltip(
#                 `&lt;div&gt;
#                      BAW180
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_fa5218be2b6058787cd1cd96bc895098 = L.polyline(
#                 [[42.605, -71.6444], [42.7261, -71.5436]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0d4b00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#0d4b00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.4}
#             ).addTo(map_ee2c81c31445e4f84b2d1a7cedd69ac4);
#
#
#         var popup_3d3115cbb390eac555c8c7313dd719fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_04c25c7473ec80846bc85bbb42fa
